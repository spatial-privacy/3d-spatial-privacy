# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib as mpl

import math
import numpy as np
import pandas as pd
import tensorflow as tf
import socket
import importlib
import os
import sys
#BASE_DIR = os.path.dirname(os.path.abspath(__file__))
#sys.path.append(BASE_DIR)
from pointnetvlad_eval_with_scores_arcore import *
from sklearn.neighbors import NearestNeighbors, KDTree
# Out:
# /home/jaybie/.conda/envs/mr-environment/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# /srv/jaybie/archive/spatial-privacy-master/pointnetvlad_arcore_submaps/
# Trajectories Loaded.
# ['ref_dataset_0', 'ref_dataset_1']
# Training df for: ref_dataset_0
# Training df for: ref_dataset_1

# %%
QUERY_PATH = 'pointnetvlad_arcore_submaps/'

RESULTS_FOLDER="testing_results/pointnetvlad_arcore/"
if not os.path.exists(RESULTS_FOLDER): os.mkdir(RESULTS_FOLDER)

# %% [markdown]
# # Step 3.1.1: One-time partial release case: inference using pointnetvlad

# %%
pickle_file = 'partial_results_extended_ref.pickle'

try:
    with open(RESULTS_FOLDER + pickle_file,'rb') as pickle_output:
        results_pickle = pickle.load(pickle_output)
        
    print(pickle_file,"exists; last item",results_pickle[-1][0])

except:
    print("No pickle file yet:",pickle_file)
    results_pickle = []
    
for radius in np.arange(3.0,5.1,0.5):
    
    query_fol = 'partial_radius_'+str(radius)
    
    QUERY_FILE = QUERY_PATH+'3d_{}_evaluation_query.pickle'.format(query_fol)
    
    output_file = RESULTS_FOLDER +pickle_file+query_fol+'.txt'
    
    QUERY_SETS= get_sets_dict(QUERY_FILE)

    query_partial_path = os.path.join(QUERY_PATH,query_fol)

    df_test= pd.read_csv(os.path.join(query_partial_path,"pointcloud_centroids_4m.csv"),sep=',')
    
    QUERY_DATABASE_NUMPY = np.asarray(df_test)
    
    print("Doing",QUERY_FILE,query_partial_path)
    
    ave_recall, ave_intra_dist, test_recall = evaluate(QUERY_SETS, QUERY_DATABASE_NUMPY, output_file)
    
    print(len(test_recall))
    
    results_pickle.append([
            radius,
            ave_recall,
            ave_intra_dist,
            test_recall
    ])

    with open(RESULTS_FOLDER + pickle_file,'wb') as pickle_output:
        pickle.dump(results_pickle,pickle_output)
# Out:
# partial_results_extended_ref.pickle exists; last item 2.5
# Trajectories Loaded.
# Doing pointnetvlad_arcore_submaps/3d_partial_radius_3.0_evaluation_query.pickle pointnetvlad_arcore_submaps/partial_radius_3.0
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (1000, 256)
# 0 0 Database output: (7927, 256) Queries output: (1000, 256)
# 1 0 Database output: (9439, 256) Queries output: (1000, 256)
#  Average Inter-space Error: 0.6775
#  Ave Intra-space Distance Error: 1.6380069205657755
#  Average similarity: 0.9541449
# 2
# Trajectories Loaded.
# Doing pointnetvlad_arcore_submaps/3d_partial_radius_3.5_evaluation_query.pickle pointnetvlad_arcore_submaps/partial_radius_3.5
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (7501, 256)
# 0 0 Database output: (7927, 256) Queries output: (7501, 256)
# 1 0 Database output: (9439, 256) Queries output: (7501, 256)
#  Average Inter-space Error: 0.7325689908012265
#  Ave Intra-space Distance Error: 1.7870726652724076
#  Average similarity: 0.9494435
# 2
# Trajectories Loaded.
# Doing pointnetvlad_arcore_submaps/3d_partial_radius_4.0_evaluation_query.pickle pointnetvlad_arcore_submaps/partial_radius_4.0
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (9607, 256)
# 0 0 Database output: (7927, 256) Queries output: (9607, 256)
# 1 0 Database output: (9439, 256) Queries output: (9607, 256)
#  Average Inter-space Error: 0.7263974185489748
#  Ave Intra-space Distance Error: 1.8391274871642587
#  Average similarity: 0.9524133
# 2
# Trajectories Loaded.
# Doing pointnetvlad_arcore_submaps/3d_partial_radius_4.5_evaluation_query.pickle pointnetvlad_arcore_submaps/partial_radius_4.5
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (11581, 256)
# 0 0 Database output: (7927, 256) Queries output: (11581, 256)
# 1 0 Database output: (9439, 256) Queries output: (11581, 256)
#  Average Inter-space Error: 0.7144892496330195
#  Ave Intra-space Distance Error: 1.9281481588045357
#  Average similarity: 0.9540783
# 2
# Trajectories Loaded.
# Doing pointnetvlad_arcore_submaps/3d_partial_radius_5.0_evaluation_query.pickle pointnetvlad_arcore_submaps/partial_radius_5.0
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (13202, 256)
# 0 0 Database output: (7927, 256) Queries output: (13202, 256)
# 1 0 Database output: (9439, 256) Queries output: (13202, 256)
#  Average Inter-space Error: 0.7125435540069687
#  Ave Intra-space Distance Error: 1.9607208913870637
#  Average similarity: 0.9539611
# 2

# %% [markdown]
# # Step 3.1.2: Results: One-time release case with pointnetVLAD (vs NN-matcher)

# %%
pickle_file = 'partial_results.pickle'

try:
    with open(RESULTS_FOLDER + pickle_file,'rb') as pickle_output:
        results_pickle = pickle.load(pickle_output)
except:
    print("No results.")
    
pointnetvlad = []

for radius, recall, intra_dist, test_recall in results_pickle:

    count_diff = 0

    for m, n, top1_obj_cands in test_recall:
        label_diff = top1_obj_cands[:,0] - top1_obj_cands[:,1]
        count_diff += np.count_nonzero(label_diff==0)/len(top1_obj_cands)

    #count_diff/len(test_recall), count_diff/len(test_recall)+ave_recall[0]

    pointnetvlad.append([
        radius,
        recall[0],
        intra_dist[0],
        count_diff/len(test_recall)
    ])
    
pointnetvlad = np.asarray(pointnetvlad)

pickle_file = 'partial_results_updated_refs.pickle'
#RESULTS_FOLDER="testing_results/pointnetvlad_prod_2/"

try:
    with open("testing_results/pointnetvlad_prod_2/" + pickle_file,'rb') as pickle_output:
        results_pickle = pickle.load(pickle_output)
except:
    print("No results.")
    
pointnetvlad_hololens = []

for radius, recall, intra_dist, test_recall in results_pickle:

    count_diff = 0

    for m, n, top1_obj_cands in test_recall:
        label_diff = top1_obj_cands[:,0] - top1_obj_cands[:,1]
        count_diff += np.count_nonzero(label_diff==0)/len(top1_obj_cands)

    #count_diff/len(test_recall), count_diff/len(test_recall)+ave_recall[0]

    pointnetvlad_hololens.append([
        radius,
        recall[0],
        intra_dist[0],
        count_diff/len(test_recall)
    ])
    
pointnetvlad_hololens = np.asarray(pointnetvlad_hololens)

with open('testing_results/partial/results_partials_nn_matcher.pickle', 'rb') as f:
    hololens_results_partials = pickle.load(f)
    
with open('testing_results/nn_matcher_arcore/arcore_results_partials_nn_matcher.pickle', 'rb') as f:
    arcore_errors = pickle.load(f)

# %%
fig=plt.figure(figsize=(12, 3))

ax1 = fig.add_subplot(121) 

ax1.grid(alpha = 0.7)
ax1.set_ylim(-0.025,1.025)
ax1.set_xlim(0,3.0)
ax1.set_ylabel("INTER-space Privacy, $\Pi_1$", fontsize = 14)
ax1.set_xlabel("Partial Radius (m)", fontsize = 14)

ax1.set_xticklabels(np.arange(0,3.1,0.5),fontsize=12)
ax1.set_yticks(np.arange(0,1.1,0.2))
ax1.set_yticklabels(np.around(np.arange(0,1.1,0.2), decimals = 1),fontsize=12)

markersize = 8
linewidth = 1.75

RansacNN = np.asarray(hololens_results_partials[1])
ARCoreNN = np.asarray(arcore_errors)

ax1.plot(
    RansacNN[:,0],
    RansacNN[:,1],
    "-o",
    linewidth = linewidth,
    fillstyle = 'none',
    mew = linewidth,markersize = markersize,
    label = "NN-matcher, HoloLens"
)
ax1.plot(
    ARCoreNN[:,0],
    ARCoreNN[:,1],
    "-s",
    linewidth = linewidth,
    fillstyle = 'none',
    mew = linewidth,markersize = markersize,
    label = "NN-matcher, ARCore"
)

ax1.plot(
    pointnetvlad_hololens[::2,0],
    pointnetvlad_hololens[::2,1],
    ":o",
    linewidth = linewidth,fillstyle = 'none',
    mew = linewidth,markersize = markersize,
    label = "pointnetvlad, HoloLens"
)

ax1.plot(
    pointnetvlad[::2,0],
    pointnetvlad[::2,1],
    ":s",
    linewidth = linewidth,fillstyle = 'none',
    mew = linewidth,markersize = markersize,
    label = "pointnetvlad, ARCore"
)

ax1.legend(loc = "lower left", ncol = 1, fontsize = 8);

ax2 = fig.add_subplot(122) 

ax2.grid(alpha = 0.7)
ax2.set_ylim(-0.25,10.25)
ax2.set_xlim(0,3)

ax2.set_ylabel("INTRA-space Privacy, $\Pi_2$ (m)", fontsize = 14, labelpad = -1.0)
ax2.set_xlabel("Partial Radius (m)", fontsize = 14)

ax2.set_xticklabels(np.arange(0,3.1,0.5),fontsize=12)
ax2.set_yticks(np.arange(0,11,2))
ax2.set_yticklabels(np.arange(0,11,2),fontsize=12)

ax2.plot(
    RansacNN[:,0],
    RansacNN[:,2],
    '-o',
    linewidth = linewidth,
    fillstyle = 'none',
    mew = linewidth,markersize = markersize,
    label = "NN-matcher, HoloLens"
)
ax2.plot(
    ARCoreNN[:,0],
    ARCoreNN[:,2],
    '-s',
    linewidth = linewidth,
    fillstyle = 'none',
    mew = linewidth,markersize = markersize,
    label = "NN-matcher, ARCore"
)
ax2.plot(
    pointnetvlad_hololens[::2,0],
    pointnetvlad_hololens[::2,2],
    ":o",
    linewidth = linewidth,fillstyle = 'none',
    mew = linewidth,markersize = markersize,
    label = "pointnetvlad, HoloLens"
)

ax2.plot(
    pointnetvlad[::2,0],
    pointnetvlad[::2,2],
    ":s",
    linewidth = linewidth,fillstyle = 'none',
    mew = linewidth,markersize = markersize,
    label = "pointnetvlad, ARCore"
)

#ax2.legend(loc = "center right", ncol = 1, fontsize = 8);

plt.savefig('plots/partials-radius-with-arcore.png', format='png', dpi=300,bbox_inches = 'tight')
plt.savefig('plots/partials-radius-with-arcore.pdf', format='pdf', dpi=300,bbox_inches = 'tight')

# %% [markdown]
# # Step 3.2.1: Successive case: spatial inference using pointnetvlad

# %%
for radius in np.arange(0.5,2.1,0.5):
    
    pickle_file = 'successive_results_'+str(radius)+'_updated_refs.pickle'

    try:
        with open(RESULTS_FOLDER + pickle_file,'rb') as pickle_output:
            results_pickle = pickle.load(pickle_output)
    except:
        print("No "+pickle_file+" file yet.")
        results_pickle = []

    successive_path = 'successive_radius_'+str(radius)
    
    for release in np.arange(1,100,5):

        query_fol = 'release_'+str(release)

        QUERY_FILE = 'pointnetvlad_submaps/successive_queries/3d_jittered_{}_evaluation_query.pickle'.format(successive_path+"_"+query_fol)

        output_file = RESULTS_FOLDER +pickle_file+query_fol+'.txt'

        QUERY_SETS= get_sets_dict(QUERY_FILE)

        query_partial_path = os.path.join(QUERY_PATH,successive_path,query_fol)

        df_test= pd.read_csv(os.path.join(query_partial_path,"pointcloud_centroids_4m.csv"),sep=',')

        QUERY_DATABASE_NUMPY = np.asarray(df_test)

        print("Doing",QUERY_FILE,query_partial_path)

        ave_recall, ave_intra_dist, test_recall = evaluate(QUERY_SETS, QUERY_DATABASE_NUMPY, output_file)

        results_pickle.append([
                release,
                ave_recall,
                ave_intra_dist
            ])

        with open(RESULTS_FOLDER + pickle_file,'wb') as pickle_output:
            pickle.dump(results_pickle,pickle_output)
# Out:
# No successive_results_0.5_updated_refs.pickle file yet.
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_0.5_release_1_evaluation_query.pickle pointnetvlad_submaps/successive_radius_0.5/release_1
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (226, 256)
# 0 0 Database output: (27912, 256) Queries output: (226, 256)
# 1 0 Database output: (27347, 256) Queries output: (226, 256)
#  Average Inter-space Error: 0.8451327433628318
#  Ave Intra-space Distance Error: 1.5377051941105806
#  Average similarity: 0.8069324
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_0.5_release_6_evaluation_query.pickle pointnetvlad_submaps/successive_radius_0.5/release_6
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (166, 256)
# 0 0 Database output: (27912, 256) Queries output: (166, 256)
# 1 0 Database output: (27347, 256) Queries output: (166, 256)
#  Average Inter-space Error: 0.6837349397590362
#  Ave Intra-space Distance Error: 2.3425545115135957
#  Average similarity: 0.88635856
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_0.5_release_11_evaluation_query.pickle pointnetvlad_submaps/successive_radius_0.5/release_11
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (164, 256)
# 0 0 Database output: (27912, 256) Queries output: (164, 256)
# 1 0 Database output: (27347, 256) Queries output: (164, 256)
#  Average Inter-space Error: 0.6432926829268293
#  Ave Intra-space Distance Error: 2.384226928435531
#  Average similarity: 0.8927561
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_0.5_release_16_evaluation_query.pickle pointnetvlad_submaps/successive_radius_0.5/release_16
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (154, 256)
# 0 0 Database output: (27912, 256) Queries output: (154, 256)
# 1 0 Database output: (27347, 256) Queries output: (154, 256)
#  Average Inter-space Error: 0.5811688311688312
#  Ave Intra-space Distance Error: 2.9476469596336052
#  Average similarity: 0.8988548
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_0.5_release_21_evaluation_query.pickle pointnetvlad_submaps/successive_radius_0.5/release_21
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (150, 256)
# 0 0 Database output: (27912, 256) Queries output: (150, 256)
# 1 0 Database output: (27347, 256) Queries output: (150, 256)
#  Average Inter-space Error: 0.5800000000000001
#  Ave Intra-space Distance Error: 2.2413588122561063
#  Average similarity: 0.93766624
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_0.5_release_26_evaluation_query.pickle pointnetvlad_submaps/successive_radius_0.5/release_26
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (161, 256)
# 0 0 Database output: (27912, 256) Queries output: (161, 256)
# 1 0 Database output: (27347, 256) Queries output: (161, 256)
#  Average Inter-space Error: 0.531055900621118
#  Ave Intra-space Distance Error: 2.843752174038179
#  Average similarity: 0.9234134
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_0.5_release_31_evaluation_query.pickle pointnetvlad_submaps/successive_radius_0.5/release_31
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (150, 256)
# 0 0 Database output: (27912, 256) Queries output: (150, 256)
# 1 0 Database output: (27347, 256) Queries output: (150, 256)
#  Average Inter-space Error: 0.4866666666666666
#  Ave Intra-space Distance Error: 3.096956148557487
#  Average similarity: 0.931554
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_0.5_release_36_evaluation_query.pickle pointnetvlad_submaps/successive_radius_0.5/release_36
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (155, 256)
# 0 0 Database output: (27912, 256) Queries output: (155, 256)
# 1 0 Database output: (27347, 256) Queries output: (155, 256)
#  Average Inter-space Error: 0.403225806451613
#  Ave Intra-space Distance Error: 3.3007350306894336
#  Average similarity: 0.9232275
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_0.5_release_41_evaluation_query.pickle pointnetvlad_submaps/successive_radius_0.5/release_41
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (151, 256)
# 0 0 Database output: (27912, 256) Queries output: (151, 256)
# 1 0 Database output: (27347, 256) Queries output: (151, 256)
#  Average Inter-space Error: 0.4039735099337749
#  Ave Intra-space Distance Error: 3.555342031301855
#  Average similarity: 0.9423782
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_0.5_release_46_evaluation_query.pickle pointnetvlad_submaps/successive_radius_0.5/release_46
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (168, 256)
# 0 0 Database output: (27912, 256) Queries output: (168, 256)
# 1 0 Database output: (27347, 256) Queries output: (168, 256)
#  Average Inter-space Error: 0.3452380952380951
#  Ave Intra-space Distance Error: 3.905871241109873
#  Average similarity: 0.9429384
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_0.5_release_51_evaluation_query.pickle pointnetvlad_submaps/successive_radius_0.5/release_51
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (150, 256)
# 0 0 Database output: (27912, 256) Queries output: (150, 256)
# 1 0 Database output: (27347, 256) Queries output: (150, 256)
#  Average Inter-space Error: 0.33999999999999997
#  Ave Intra-space Distance Error: 3.8292960719946376
#  Average similarity: 0.9527991
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_0.5_release_56_evaluation_query.pickle pointnetvlad_submaps/successive_radius_0.5/release_56
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (158, 256)
# 0 0 Database output: (27912, 256) Queries output: (158, 256)
# 1 0 Database output: (27347, 256) Queries output: (158, 256)
#  Average Inter-space Error: 0.3512658227848101
#  Ave Intra-space Distance Error: 3.693725380265307
#  Average similarity: 0.94988
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_0.5_release_61_evaluation_query.pickle pointnetvlad_submaps/successive_radius_0.5/release_61
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (154, 256)
# 0 0 Database output: (27912, 256) Queries output: (154, 256)
# 1 0 Database output: (27347, 256) Queries output: (154, 256)
#  Average Inter-space Error: 0.28246753246753253
#  Ave Intra-space Distance Error: 4.136108852126281
#  Average similarity: 0.95171416
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_0.5_release_66_evaluation_query.pickle pointnetvlad_submaps/successive_radius_0.5/release_66
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (181, 256)
# 0 0 Database output: (27912, 256) Queries output: (181, 256)
# 1 0 Database output: (27347, 256) Queries output: (181, 256)
#  Average Inter-space Error: 0.33977900552486184
#  Ave Intra-space Distance Error: 3.553090735106834
#  Average similarity: 0.94786817
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_0.5_release_71_evaluation_query.pickle pointnetvlad_submaps/successive_radius_0.5/release_71
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (148, 256)
# 0 0 Database output: (27912, 256) Queries output: (148, 256)
# 1 0 Database output: (27347, 256) Queries output: (148, 256)
#  Average Inter-space Error: 0.2702702702702703
#  Ave Intra-space Distance Error: 3.970229308664815
#  Average similarity: 0.96324754
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_0.5_release_76_evaluation_query.pickle pointnetvlad_submaps/successive_radius_0.5/release_76
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (164, 256)
# 0 0 Database output: (27912, 256) Queries output: (164, 256)
# 1 0 Database output: (27347, 256) Queries output: (164, 256)
#  Average Inter-space Error: 0.25
#  Ave Intra-space Distance Error: 4.090272724891088
#  Average similarity: 0.9524975
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_0.5_release_81_evaluation_query.pickle pointnetvlad_submaps/successive_radius_0.5/release_81
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (160, 256)
# 0 0 Database output: (27912, 256) Queries output: (160, 256)
# 1 0 Database output: (27347, 256) Queries output: (160, 256)
#  Average Inter-space Error: 0.2875
#  Ave Intra-space Distance Error: 3.7080999577413887
#  Average similarity: 0.95875144
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_0.5_release_86_evaluation_query.pickle pointnetvlad_submaps/successive_radius_0.5/release_86
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (153, 256)
# 0 0 Database output: (27912, 256) Queries output: (153, 256)
# 1 0 Database output: (27347, 256) Queries output: (153, 256)
#  Average Inter-space Error: 0.19934640522875813
#  Ave Intra-space Distance Error: 3.937059163321826
#  Average similarity: 0.9567673
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_0.5_release_91_evaluation_query.pickle pointnetvlad_submaps/successive_radius_0.5/release_91
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (142, 256)
# 0 0 Database output: (27912, 256) Queries output: (142, 256)
# 1 0 Database output: (27347, 256) Queries output: (142, 256)
#  Average Inter-space Error: 0.26056338028169024
#  Ave Intra-space Distance Error: 4.164569171097692
#  Average similarity: 0.96082085
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_0.5_release_96_evaluation_query.pickle pointnetvlad_submaps/successive_radius_0.5/release_96
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (168, 256)
# 0 0 Database output: (27912, 256) Queries output: (168, 256)
# 1 0 Database output: (27347, 256) Queries output: (168, 256)
#  Average Inter-space Error: 0.1875
#  Ave Intra-space Distance Error: 4.098826502616021
#  Average similarity: 0.9538679
# No successive_results_1.0_updated_refs.pickle file yet.
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_1.0_release_1_evaluation_query.pickle pointnetvlad_submaps/successive_radius_1.0/release_1
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (160, 256)
# 0 0 Database output: (27912, 256) Queries output: (160, 256)
# 1 0 Database output: (27347, 256) Queries output: (160, 256)
#  Average Inter-space Error: 0.7625
#  Ave Intra-space Distance Error: 2.1098451303519012
#  Average similarity: 0.86315817
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_1.0_release_6_evaluation_query.pickle pointnetvlad_submaps/successive_radius_1.0/release_6
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (145, 256)
# 0 0 Database output: (27912, 256) Queries output: (145, 256)
# 1 0 Database output: (27347, 256) Queries output: (145, 256)
#  Average Inter-space Error: 0.5517241379310345
#  Ave Intra-space Distance Error: 2.659347874445279
#  Average similarity: 0.9108327
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_1.0_release_11_evaluation_query.pickle pointnetvlad_submaps/successive_radius_1.0/release_11
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (164, 256)
# 0 0 Database output: (27912, 256) Queries output: (164, 256)
# 1 0 Database output: (27347, 256) Queries output: (164, 256)
#  Average Inter-space Error: 0.3414634146341463
#  Ave Intra-space Distance Error: 3.536266712723555
#  Average similarity: 0.9574487
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_1.0_release_16_evaluation_query.pickle pointnetvlad_submaps/successive_radius_1.0/release_16
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (154, 256)
# 0 0 Database output: (27912, 256) Queries output: (154, 256)
# 1 0 Database output: (27347, 256) Queries output: (154, 256)
#  Average Inter-space Error: 0.3246753246753247
#  Ave Intra-space Distance Error: 3.781106447696949
#  Average similarity: 0.95224375
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_1.0_release_21_evaluation_query.pickle pointnetvlad_submaps/successive_radius_1.0/release_21
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (153, 256)
# 0 0 Database output: (27912, 256) Queries output: (153, 256)
# 1 0 Database output: (27347, 256) Queries output: (153, 256)
#  Average Inter-space Error: 0.24836601307189543
#  Ave Intra-space Distance Error: 3.9602136255551867
#  Average similarity: 0.96319085
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_1.0_release_26_evaluation_query.pickle pointnetvlad_submaps/successive_radius_1.0/release_26
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (161, 256)
# 0 0 Database output: (27912, 256) Queries output: (161, 256)
# 1 0 Database output: (27347, 256) Queries output: (161, 256)
#  Average Inter-space Error: 0.18322981366459623
#  Ave Intra-space Distance Error: 4.495070076717466
#  Average similarity: 0.9572227
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_1.0_release_31_evaluation_query.pickle pointnetvlad_submaps/successive_radius_1.0/release_31
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (153, 256)
# 0 0 Database output: (27912, 256) Queries output: (153, 256)
# 1 0 Database output: (27347, 256) Queries output: (153, 256)
#  Average Inter-space Error: 0.1895424836601307
#  Ave Intra-space Distance Error: 4.22473438641625
#  Average similarity: 0.9718021
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_1.0_release_36_evaluation_query.pickle pointnetvlad_submaps/successive_radius_1.0/release_36
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (152, 256)
# 0 0 Database output: (27912, 256) Queries output: (152, 256)
# 1 0 Database output: (27347, 256) Queries output: (152, 256)
#  Average Inter-space Error: 0.1875
#  Ave Intra-space Distance Error: 4.3049109347345915
#  Average similarity: 0.9681264
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_1.0_release_41_evaluation_query.pickle pointnetvlad_submaps/successive_radius_1.0/release_41
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (169, 256)
# 0 0 Database output: (27912, 256) Queries output: (169, 256)
# 1 0 Database output: (27347, 256) Queries output: (169, 256)
#  Average Inter-space Error: 0.12130177514792906
#  Ave Intra-space Distance Error: 4.547084232657492
#  Average similarity: 0.97687405
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_1.0_release_46_evaluation_query.pickle pointnetvlad_submaps/successive_radius_1.0/release_46
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (188, 256)
# 0 0 Database output: (27912, 256) Queries output: (188, 256)
# 1 0 Database output: (27347, 256) Queries output: (188, 256)
#  Average Inter-space Error: 0.11702127659574468
#  Ave Intra-space Distance Error: 4.445875762868036
#  Average similarity: 0.9714186
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_1.0_release_51_evaluation_query.pickle pointnetvlad_submaps/successive_radius_1.0/release_51
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (134, 256)
# 0 0 Database output: (27912, 256) Queries output: (134, 256)
# 1 0 Database output: (27347, 256) Queries output: (134, 256)
#  Average Inter-space Error: 0.13059701492537323
#  Ave Intra-space Distance Error: 4.407403343750628
#  Average similarity: 0.9754416
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_1.0_release_56_evaluation_query.pickle pointnetvlad_submaps/successive_radius_1.0/release_56
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (161, 256)
# 0 0 Database output: (27912, 256) Queries output: (161, 256)
# 1 0 Database output: (27347, 256) Queries output: (161, 256)
#  Average Inter-space Error: 0.13043478260869557
#  Ave Intra-space Distance Error: 4.590004152707152
#  Average similarity: 0.96988636
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_1.0_release_61_evaluation_query.pickle pointnetvlad_submaps/successive_radius_1.0/release_61
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (164, 256)
# 0 0 Database output: (27912, 256) Queries output: (164, 256)
# 1 0 Database output: (27347, 256) Queries output: (164, 256)
#  Average Inter-space Error: 0.11280487804878048
#  Ave Intra-space Distance Error: 4.452220076159584
#  Average similarity: 0.971415
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_1.0_release_66_evaluation_query.pickle pointnetvlad_submaps/successive_radius_1.0/release_66
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (163, 256)
# 0 0 Database output: (27912, 256) Queries output: (163, 256)
# 1 0 Database output: (27347, 256) Queries output: (163, 256)
#  Average Inter-space Error: 0.11042944785276065
#  Ave Intra-space Distance Error: 4.61352141459477
#  Average similarity: 0.9746976
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_1.0_release_71_evaluation_query.pickle pointnetvlad_submaps/successive_radius_1.0/release_71
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (160, 256)
# 0 0 Database output: (27912, 256) Queries output: (160, 256)
# 1 0 Database output: (27347, 256) Queries output: (160, 256)
#  Average Inter-space Error: 0.09062499999999996
#  Ave Intra-space Distance Error: 4.606383527120833
#  Average similarity: 0.96905434
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_1.0_release_76_evaluation_query.pickle pointnetvlad_submaps/successive_radius_1.0/release_76
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (175, 256)
# 0 0 Database output: (27912, 256) Queries output: (175, 256)
# 1 0 Database output: (27347, 256) Queries output: (175, 256)
#  Average Inter-space Error: 0.10571428571428587
#  Ave Intra-space Distance Error: 4.457515484274428
#  Average similarity: 0.9729913
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_1.0_release_81_evaluation_query.pickle pointnetvlad_submaps/successive_radius_1.0/release_81
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (173, 256)
# 0 0 Database output: (27912, 256) Queries output: (173, 256)
# 1 0 Database output: (27347, 256) Queries output: (173, 256)
#  Average Inter-space Error: 0.09248554913294793
#  Ave Intra-space Distance Error: 4.640695552782281
#  Average similarity: 0.97626656
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_1.0_release_86_evaluation_query.pickle pointnetvlad_submaps/successive_radius_1.0/release_86
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (150, 256)
# 0 0 Database output: (27912, 256) Queries output: (150, 256)
# 1 0 Database output: (27347, 256) Queries output: (150, 256)
#  Average Inter-space Error: 0.08999999999999997
#  Ave Intra-space Distance Error: 4.7143093078912655
#  Average similarity: 0.97703534
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_1.0_release_91_evaluation_query.pickle pointnetvlad_submaps/successive_radius_1.0/release_91
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (153, 256)
# 0 0 Database output: (27912, 256) Queries output: (153, 256)
# 1 0 Database output: (27347, 256) Queries output: (153, 256)
#  Average Inter-space Error: 0.10784313725490191
#  Ave Intra-space Distance Error: 4.496933605238558
#  Average similarity: 0.9733954
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_1.0_release_96_evaluation_query.pickle pointnetvlad_submaps/successive_radius_1.0/release_96
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (157, 256)
# 0 0 Database output: (27912, 256) Queries output: (157, 256)
# 1 0 Database output: (27347, 256) Queries output: (157, 256)
#  Average Inter-space Error: 0.10509554140127386
#  Ave Intra-space Distance Error: 4.421935800660928
#  Average similarity: 0.9722998
# No successive_results_1.5_updated_refs.pickle file yet.
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_1.5_release_1_evaluation_query.pickle pointnetvlad_submaps/successive_radius_1.5/release_1
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (142, 256)
# 0 0 Database output: (27912, 256) Queries output: (142, 256)
# 1 0 Database output: (27347, 256) Queries output: (142, 256)
#  Average Inter-space Error: 0.6161971830985915
#  Ave Intra-space Distance Error: 2.7801257749778374
#  Average similarity: 0.8725176
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_1.5_release_6_evaluation_query.pickle pointnetvlad_submaps/successive_radius_1.5/release_6
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (149, 256)
# 0 0 Database output: (27912, 256) Queries output: (149, 256)
# 1 0 Database output: (27347, 256) Queries output: (149, 256)
#  Average Inter-space Error: 0.25503355704697983
#  Ave Intra-space Distance Error: 3.9370901840621766
#  Average similarity: 0.94442225
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_1.5_release_11_evaluation_query.pickle pointnetvlad_submaps/successive_radius_1.5/release_11
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (151, 256)
# 0 0 Database output: (27912, 256) Queries output: (151, 256)
# 1 0 Database output: (27347, 256) Queries output: (151, 256)
#  Average Inter-space Error: 0.16556291390728473
#  Ave Intra-space Distance Error: 4.389980097067944
#  Average similarity: 0.96639806
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_1.5_release_16_evaluation_query.pickle pointnetvlad_submaps/successive_radius_1.5/release_16
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (154, 256)
# 0 0 Database output: (27912, 256) Queries output: (154, 256)
# 1 0 Database output: (27347, 256) Queries output: (154, 256)
#  Average Inter-space Error: 0.17532467532467533
#  Ave Intra-space Distance Error: 4.096317004588837
#  Average similarity: 0.96917325
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_1.5_release_21_evaluation_query.pickle pointnetvlad_submaps/successive_radius_1.5/release_21
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (154, 256)
# 0 0 Database output: (27912, 256) Queries output: (154, 256)
# 1 0 Database output: (27347, 256) Queries output: (154, 256)
#  Average Inter-space Error: 0.1428571428571428
#  Ave Intra-space Distance Error: 4.439435495795312
#  Average similarity: 0.9724201
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_1.5_release_26_evaluation_query.pickle pointnetvlad_submaps/successive_radius_1.5/release_26
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (173, 256)
# 0 0 Database output: (27912, 256) Queries output: (173, 256)
# 1 0 Database output: (27347, 256) Queries output: (173, 256)
#  Average Inter-space Error: 0.06358381502890165
#  Ave Intra-space Distance Error: 4.686803305165357
#  Average similarity: 0.97529924
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_1.5_release_31_evaluation_query.pickle pointnetvlad_submaps/successive_radius_1.5/release_31
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (166, 256)
# 0 0 Database output: (27912, 256) Queries output: (166, 256)
# 1 0 Database output: (27347, 256) Queries output: (166, 256)
#  Average Inter-space Error: 0.09638554216867457
#  Ave Intra-space Distance Error: 4.586856891000187
#  Average similarity: 0.96759117
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_1.5_release_36_evaluation_query.pickle pointnetvlad_submaps/successive_radius_1.5/release_36
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (179, 256)
# 0 0 Database output: (27912, 256) Queries output: (179, 256)
# 1 0 Database output: (27347, 256) Queries output: (179, 256)
#  Average Inter-space Error: 0.06983240223463694
#  Ave Intra-space Distance Error: 4.601283345968239
#  Average similarity: 0.9765525
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_1.5_release_41_evaluation_query.pickle pointnetvlad_submaps/successive_radius_1.5/release_41
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (149, 256)
# 0 0 Database output: (27912, 256) Queries output: (149, 256)
# 1 0 Database output: (27347, 256) Queries output: (149, 256)
#  Average Inter-space Error: 0.11744966442953031
#  Ave Intra-space Distance Error: 4.357756180337747
#  Average similarity: 0.9769025
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_1.5_release_46_evaluation_query.pickle pointnetvlad_submaps/successive_radius_1.5/release_46
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (153, 256)
# 0 0 Database output: (27912, 256) Queries output: (153, 256)
# 1 0 Database output: (27347, 256) Queries output: (153, 256)
#  Average Inter-space Error: 0.11111111111111116
#  Ave Intra-space Distance Error: 4.757425542116364
#  Average similarity: 0.974144
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_1.5_release_51_evaluation_query.pickle pointnetvlad_submaps/successive_radius_1.5/release_51
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (171, 256)
# 0 0 Database output: (27912, 256) Queries output: (171, 256)
# 1 0 Database output: (27347, 256) Queries output: (171, 256)
#  Average Inter-space Error: 0.04678362573099415
#  Ave Intra-space Distance Error: 4.730244019823919
#  Average similarity: 0.97668767
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_1.5_release_56_evaluation_query.pickle pointnetvlad_submaps/successive_radius_1.5/release_56
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (152, 256)
# 0 0 Database output: (27912, 256) Queries output: (152, 256)
# 1 0 Database output: (27347, 256) Queries output: (152, 256)
#  Average Inter-space Error: 0.06907894736842113
#  Ave Intra-space Distance Error: 4.64602215157648
#  Average similarity: 0.97754455
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_1.5_release_61_evaluation_query.pickle pointnetvlad_submaps/successive_radius_1.5/release_61
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (162, 256)
# 0 0 Database output: (27912, 256) Queries output: (162, 256)
# 1 0 Database output: (27347, 256) Queries output: (162, 256)
#  Average Inter-space Error: 0.11111111111111116
#  Ave Intra-space Distance Error: 4.517772808827186
#  Average similarity: 0.9784426
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_1.5_release_66_evaluation_query.pickle pointnetvlad_submaps/successive_radius_1.5/release_66
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (170, 256)
# 0 0 Database output: (27912, 256) Queries output: (170, 256)
# 1 0 Database output: (27347, 256) Queries output: (170, 256)
#  Average Inter-space Error: 0.08235294117647052
#  Ave Intra-space Distance Error: 4.935283202446607
#  Average similarity: 0.97395384
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_1.5_release_71_evaluation_query.pickle pointnetvlad_submaps/successive_radius_1.5/release_71
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (132, 256)
# 0 0 Database output: (27912, 256) Queries output: (132, 256)
# 1 0 Database output: (27347, 256) Queries output: (132, 256)
#  Average Inter-space Error: 0.07196969696969702
#  Ave Intra-space Distance Error: 4.657774426660312
#  Average similarity: 0.9775305
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_1.5_release_76_evaluation_query.pickle pointnetvlad_submaps/successive_radius_1.5/release_76
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (180, 256)
# 0 0 Database output: (27912, 256) Queries output: (180, 256)
# 1 0 Database output: (27347, 256) Queries output: (180, 256)
#  Average Inter-space Error: 0.09444444444444455
#  Ave Intra-space Distance Error: 4.643545035070099
#  Average similarity: 0.97650707
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_1.5_release_81_evaluation_query.pickle pointnetvlad_submaps/successive_radius_1.5/release_81
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (145, 256)
# 0 0 Database output: (27912, 256) Queries output: (145, 256)
# 1 0 Database output: (27347, 256) Queries output: (145, 256)
#  Average Inter-space Error: 0.03448275862068961
#  Ave Intra-space Distance Error: 4.865523988377232
#  Average similarity: 0.9837545
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_1.5_release_86_evaluation_query.pickle pointnetvlad_submaps/successive_radius_1.5/release_86
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (152, 256)
# 0 0 Database output: (27912, 256) Queries output: (152, 256)
# 1 0 Database output: (27347, 256) Queries output: (152, 256)
#  Average Inter-space Error: 0.06907894736842113
#  Ave Intra-space Distance Error: 4.70474850079356
#  Average similarity: 0.9753545
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_1.5_release_91_evaluation_query.pickle pointnetvlad_submaps/successive_radius_1.5/release_91
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (153, 256)
# 0 0 Database output: (27912, 256) Queries output: (153, 256)
# 1 0 Database output: (27347, 256) Queries output: (153, 256)
#  Average Inter-space Error: 0.07843137254901955
#  Ave Intra-space Distance Error: 4.649826806830093
#  Average similarity: 0.97987777
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_1.5_release_96_evaluation_query.pickle pointnetvlad_submaps/successive_radius_1.5/release_96
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (171, 256)
# 0 0 Database output: (27912, 256) Queries output: (171, 256)
# 1 0 Database output: (27347, 256) Queries output: (171, 256)
#  Average Inter-space Error: 0.07602339181286555
#  Ave Intra-space Distance Error: 4.847342108223211
#  Average similarity: 0.972899
# No successive_results_2.0_updated_refs.pickle file yet.
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_2.0_release_1_evaluation_query.pickle pointnetvlad_submaps/successive_radius_2.0/release_1
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (165, 256)
# 0 0 Database output: (27912, 256) Queries output: (165, 256)
# 1 0 Database output: (27347, 256) Queries output: (165, 256)
#  Average Inter-space Error: 0.4606060606060606
#  Ave Intra-space Distance Error: 3.2535820100251893
#  Average similarity: 0.9253762
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_2.0_release_6_evaluation_query.pickle pointnetvlad_submaps/successive_radius_2.0/release_6
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (159, 256)
# 0 0 Database output: (27912, 256) Queries output: (159, 256)
# 1 0 Database output: (27347, 256) Queries output: (159, 256)
#  Average Inter-space Error: 0.13207547169811318
#  Ave Intra-space Distance Error: 4.411200303407462
#  Average similarity: 0.9738965
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_2.0_release_11_evaluation_query.pickle pointnetvlad_submaps/successive_radius_2.0/release_11
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (143, 256)
# 0 0 Database output: (27912, 256) Queries output: (143, 256)
# 1 0 Database output: (27347, 256) Queries output: (143, 256)
#  Average Inter-space Error: 0.12937062937062926
#  Ave Intra-space Distance Error: 4.3880725043505375
#  Average similarity: 0.9710055
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_2.0_release_16_evaluation_query.pickle pointnetvlad_submaps/successive_radius_2.0/release_16
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (152, 256)
# 0 0 Database output: (27912, 256) Queries output: (152, 256)
# 1 0 Database output: (27347, 256) Queries output: (152, 256)
#  Average Inter-space Error: 0.0921052631578948
#  Ave Intra-space Distance Error: 4.613147616680806
#  Average similarity: 0.9747489
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_2.0_release_21_evaluation_query.pickle pointnetvlad_submaps/successive_radius_2.0/release_21
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (159, 256)
# 0 0 Database output: (27912, 256) Queries output: (159, 256)
# 1 0 Database output: (27347, 256) Queries output: (159, 256)
#  Average Inter-space Error: 0.11635220125786161
#  Ave Intra-space Distance Error: 4.521822321050637
#  Average similarity: 0.98038036
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_2.0_release_26_evaluation_query.pickle pointnetvlad_submaps/successive_radius_2.0/release_26
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (156, 256)
# 0 0 Database output: (27912, 256) Queries output: (156, 256)
# 1 0 Database output: (27347, 256) Queries output: (156, 256)
#  Average Inter-space Error: 0.10576923076923062
#  Ave Intra-space Distance Error: 4.717829532049148
#  Average similarity: 0.9764987
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_2.0_release_31_evaluation_query.pickle pointnetvlad_submaps/successive_radius_2.0/release_31
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (162, 256)
# 0 0 Database output: (27912, 256) Queries output: (162, 256)
# 1 0 Database output: (27347, 256) Queries output: (162, 256)
#  Average Inter-space Error: 0.09876543209876532
#  Ave Intra-space Distance Error: 4.497276345123993
#  Average similarity: 0.9791074
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_2.0_release_36_evaluation_query.pickle pointnetvlad_submaps/successive_radius_2.0/release_36
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (159, 256)
# 0 0 Database output: (27912, 256) Queries output: (159, 256)
# 1 0 Database output: (27347, 256) Queries output: (159, 256)
#  Average Inter-space Error: 0.07861635220125773
#  Ave Intra-space Distance Error: 4.381250849209325
#  Average similarity: 0.97944367
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_2.0_release_41_evaluation_query.pickle pointnetvlad_submaps/successive_radius_2.0/release_41
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (153, 256)
# 0 0 Database output: (27912, 256) Queries output: (153, 256)
# 1 0 Database output: (27347, 256) Queries output: (153, 256)
#  Average Inter-space Error: 0.06862745098039225
#  Ave Intra-space Distance Error: 4.818036278706587
#  Average similarity: 0.9803289
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_2.0_release_46_evaluation_query.pickle pointnetvlad_submaps/successive_radius_2.0/release_46
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (155, 256)
# 0 0 Database output: (27912, 256) Queries output: (155, 256)
# 1 0 Database output: (27347, 256) Queries output: (155, 256)
#  Average Inter-space Error: 0.058064516129032295
#  Ave Intra-space Distance Error: 4.816706716639963
#  Average similarity: 0.97312194
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_2.0_release_51_evaluation_query.pickle pointnetvlad_submaps/successive_radius_2.0/release_51
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (168, 256)
# 0 0 Database output: (27912, 256) Queries output: (168, 256)
# 1 0 Database output: (27347, 256) Queries output: (168, 256)
#  Average Inter-space Error: 0.06845238095238104
#  Ave Intra-space Distance Error: 4.714046428534615
#  Average similarity: 0.9767669
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_2.0_release_56_evaluation_query.pickle pointnetvlad_submaps/successive_radius_2.0/release_56
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (160, 256)
# 0 0 Database output: (27912, 256) Queries output: (160, 256)
# 1 0 Database output: (27347, 256) Queries output: (160, 256)
#  Average Inter-space Error: 0.10312500000000002
#  Ave Intra-space Distance Error: 4.634445898040122
#  Average similarity: 0.98268664
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_2.0_release_61_evaluation_query.pickle pointnetvlad_submaps/successive_radius_2.0/release_61
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (148, 256)
# 0 0 Database output: (27912, 256) Queries output: (148, 256)
# 1 0 Database output: (27347, 256) Queries output: (148, 256)
#  Average Inter-space Error: 0.07770270270270263
#  Ave Intra-space Distance Error: 4.867189853961664
#  Average similarity: 0.98373693
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_2.0_release_66_evaluation_query.pickle pointnetvlad_submaps/successive_radius_2.0/release_66
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (157, 256)
# 0 0 Database output: (27912, 256) Queries output: (157, 256)
# 1 0 Database output: (27347, 256) Queries output: (157, 256)
#  Average Inter-space Error: 0.12101910828025475
#  Ave Intra-space Distance Error: 4.561052327227992
#  Average similarity: 0.9765158
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_2.0_release_71_evaluation_query.pickle pointnetvlad_submaps/successive_radius_2.0/release_71
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (158, 256)
# 0 0 Database output: (27912, 256) Queries output: (158, 256)
# 1 0 Database output: (27347, 256) Queries output: (158, 256)
#  Average Inter-space Error: 0.08544303797468356
#  Ave Intra-space Distance Error: 4.578045072714598
#  Average similarity: 0.9820064
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_2.0_release_76_evaluation_query.pickle pointnetvlad_submaps/successive_radius_2.0/release_76
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (172, 256)
# 0 0 Database output: (27912, 256) Queries output: (172, 256)
# 1 0 Database output: (27347, 256) Queries output: (172, 256)
#  Average Inter-space Error: 0.06686046511627908
#  Ave Intra-space Distance Error: 4.7478950236673025
#  Average similarity: 0.9796517
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_2.0_release_81_evaluation_query.pickle pointnetvlad_submaps/successive_radius_2.0/release_81
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (148, 256)
# 0 0 Database output: (27912, 256) Queries output: (148, 256)
# 1 0 Database output: (27347, 256) Queries output: (148, 256)
#  Average Inter-space Error: 0.07094594594594594
#  Ave Intra-space Distance Error: 4.580139133908796
#  Average similarity: 0.9784557
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_2.0_release_86_evaluation_query.pickle pointnetvlad_submaps/successive_radius_2.0/release_86
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (163, 256)
# 0 0 Database output: (27912, 256) Queries output: (163, 256)
# 1 0 Database output: (27347, 256) Queries output: (163, 256)
#  Average Inter-space Error: 0.08895705521472397
#  Ave Intra-space Distance Error: 4.866344761725418
#  Average similarity: 0.97869444
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_2.0_release_91_evaluation_query.pickle pointnetvlad_submaps/successive_radius_2.0/release_91
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (159, 256)
# 0 0 Database output: (27912, 256) Queries output: (159, 256)
# 1 0 Database output: (27347, 256) Queries output: (159, 256)
#  Average Inter-space Error: 0.04088050314465408
#  Ave Intra-space Distance Error: 4.796064600231241
#  Average similarity: 0.982777
# Trajectories Loaded.
# Doing pointnetvlad_submaps/successive_queries/3d_jittered_successive_radius_2.0_release_96_evaluation_query.pickle pointnetvlad_submaps/successive_radius_2.0/release_96
# Tensor("query_triplets/Mul_1:0", shape=(51, 256), dtype=float32, device=/device:GPU:0)
# INFO:tensorflow:Restoring parameters from model/model_3d_4m_jittered_4096.ckpt
# Model restored.
# 0 1
# (157, 256)
# 0 0 Database output: (27912, 256) Queries output: (157, 256)
# 1 0 Database output: (27347, 256) Queries output: (157, 256)
#  Average Inter-space Error: 0.05095541401273884
#  Ave Intra-space Distance Error: 4.789717118896956
#  Average similarity: 0.9834716

# %% [markdown]
# # Step 3.2.2: Results: Successive case with pointnetVLAD (vs NN-matcher)

# %%
pointnetvlad_successive = []

for radius in np.arange(0.5,2.1,0.5):
    
    pickle_file = 'successive_results_'+str(radius)+'_updated_refs.pickle'

    pointnetvlad_successive_per_radius = []

    try:
        with open(RESULTS_FOLDER + pickle_file,'rb') as pickle_output:
            results_pickle = pickle.load(pickle_output)
    except:
        print("No results_ransac.")

    for release, recall, intra_dist in results_pickle:
        pointnetvlad_successive_per_radius.append([
            release,
            recall[0],
            intra_dist[0]
        ])

    pointnetvlad_successive_per_radius = np.asarray(pointnetvlad_successive_per_radius)#[-16:]

    pointnetvlad_successive.append(pointnetvlad_successive_per_radius)
    
with open('testing_results/successive/nn_matcher_errors.pickle', 'rb') as f:
    [succ_NN_errors,succ_NN_intra_errors] = pickle.load(f)

# %%
fig=plt.figure(figsize=(12, 3))

ax1 = fig.add_subplot(121) 

ax1.grid(alpha = 0.7)
ax1.set_ylim(-0.025,1.025)
ax1.set_xlim(0,100)
ax1.set_ylabel("INTER-space Privacy, $\Pi_1$", fontsize = 14)
ax1.set_xlabel("Number of Releases", fontsize = 14)

markersize = 7
linewidth = 1.5
#plt.minorticks_on()

for radius, inter_errors in succ_NN_errors:#[:2]:

    if radius == 1.5: continue

    #print(RawNN_per_iteration_errors.shape)
    ax1.plot(
        np.arange(1,100,10)[:len(inter_errors):]+1,
        inter_errors[::], 
        '-o', 
        linewidth = linewidth,fillstyle = 'none',
        mew = linewidth,markersize = min(markersize*(1.25/radius),markersize),
        label = "NN-matcher, r ="+ str(radius)
    )

for i, radius in enumerate(np.arange(0.5,2.1,0.5)):

    if radius == 1.5: continue

    ax1.plot(
        np.arange(1,100,10)+1,
        pointnetvlad_successive[i][::2,1],
        ":s",
        linewidth = linewidth,fillstyle = 'none',
        mew = linewidth,markersize = min(markersize*(1.25/radius),markersize),
        label = "pointnetvlad, r = "+str(radius)
    )

ax1.legend(loc = "upper right", ncol = 2, fontsize = 8);

ax2 = fig.add_subplot(122) 

ax2.grid(alpha = 0.7)
ax2.set_ylim(-0.25,10.25)
ax2.set_xlim(0,100)

ax2.set_ylabel("INTRA-space Privacy, $\Pi_2$ (m)", fontsize = 14)
ax2.set_xlabel("Number of Releases", fontsize = 14)

for radius, intra_errors in succ_NN_intra_errors:#[:2]:
    
    if radius == 1.5: continue
    
    ax2.plot(
        np.arange(1,100,10)+1,#[:len(intra_errors):2]+1,
        intra_errors[::,0], 
        '-o',
        linewidth = linewidth, #capsize = 4.0, 
        #marker = markers[0],
        fillstyle = 'none',
        mew = linewidth,markersize = min(markersize*(1.25/radius),markersize),
        label = "NN-matcher, r ="+ str(radius)
    )

for i, radius in enumerate(np.arange(0.5,2.1,0.5)):

    if radius == 1.5: continue

    ax2.plot(
        np.arange(1,100,10)+1,
        pointnetvlad_successive[i][::2,2],
        ":s",
        linewidth = linewidth,fillstyle = 'none',
        mew = linewidth,markersize = min(markersize*(1.25/radius),markersize),
        label = "pointnetvlad, r = "+str(radius)
    )


ax2.legend(loc = "upper right", ncol = 2, fontsize = 8);

plt.savefig('plots/successive-with-pointnetvlad.png', format='png', dpi=300,bbox_inches = 'tight')
